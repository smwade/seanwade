# %% [raw]
# title: 'The Second Notebook'
# date: '2021-02-01T22:12:03.284Z'
# description: 'la la la la la'
# tags:
#   - code

# %% [markdown]
# # This is a test post using Jupyter

# %%
from matplotlib import pyplot as plt
import numpy as np

plt.style.use('keynote')

# %%
data = np.random.randn(50, 2)
x, y = data[:,0], data[:,1]

# %%
plt.scatter(x, y)
plt.title('A random plot')
plt.savefig('my_plot.png', transparent=True)

# %% [markdown]
# ## This is a subsection

# %% [markdown]
# Herfajsdfkl ajsdfkl ajsdklfj asdklfj asdklfj askldjf alksjdflkasdjflaksdjfalksdfjasdklfjadksjfkadsjfka dsjakjf kasdjf kasjf kasj kjfd ksjfaksjdfkajsdfksj kfjsd kajsdfk asjdfk asjdfk ajsdkfja skfjaks djf akdj fkajf aksdjf kasjfd kasjfk ajsdkfja kdfj kajdfk asjdfkaj sdfkjad kfjqkdfjakjfdkadsljfqopeiwjfqoipefnvfoeivnqeo inqiovn qeiovnq eoivnqeonv qo

# %%
print("""for i in range(10):
    print(i)""")
# Out:
# for i in range(10):
#     print(i)

# %% [markdown]
# ```
# print('test')
# ```python
